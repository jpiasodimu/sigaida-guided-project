# %%
import pandas as pd
df = pd.read_csv("../data/stop_times.txt")
df["departure_time"]
# Out:
# 0         19:26:00
# 1         19:27:00
# 2         19:27:45
# 3         19:28:20
# 4         19:28:55
#             ...
# 213389    18:28:00
# 213390    06:10:00
# 213391    06:10:00
# 213392    07:35:00
# 213393    06:35:00
# Name: departure_time, Length: 213394, dtype: str
